# %%
import os
import SimpleITK as sitk
import numpy as np

# %%
mri=r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx"

for x,y,z in os.walk(mri):
    print(x)
# Out:
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000\4.000000-t2tsetra-00702
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000\6.000000-ep2ddifftraDYNDIST-69284
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000\7.000000-ep2ddifftraDYNDISTADC-48780
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0001
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0001\6.000000-t2tsetra-76610
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0001\7.000000-ep2ddifftraDYNDISTMIX-61648
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0001\8.000000-ep2ddifftraDYNDISTMIXADC-33954
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0002
# ...

# %%
for x,y,z in os.walk(mri):
    print(y)
# Out:
# ['ProstateX-0000', 'ProstateX-0001', 'ProstateX-0002', 'ProstateX-0003', 'ProstateX-0004', 'ProstateX-0005', 'ProstateX-0006', 'ProstateX-0007', 'ProstateX-0008', 'ProstateX-0009', 'ProstateX-0010', 'ProstateX-0011', 'ProstateX-0012', 'ProstateX-0013', 'ProstateX-0014', 'ProstateX-0015', 'ProstateX-0016', 'ProstateX-0017', 'ProstateX-0018', 'ProstateX-0019', 'ProstateX-0020', 'ProstateX-0021', 'ProstateX-0022', 'ProstateX-0023', 'ProstateX-0024', 'ProstateX-0025', 'ProstateX-0026', 'ProstateX-0027', 'ProstateX-0028', 'ProstateX-0029', 'ProstateX-0030', 'ProstateX-0031', 'ProstateX-0032', 'ProstateX-0033', 'ProstateX-0034', 'ProstateX-0035', 'ProstateX-0036', 'ProstateX-0037', 'ProstateX-0038', 'ProstateX-0039', 'ProstateX-0040', 'ProstateX-0041', 'ProstateX-0042', 'ProstateX-0043', 'ProstateX-0044', 'ProstateX-0045', 'ProstateX-0046', 'ProstateX-0047', 'ProstateX-0048', 'ProstateX-0049']
# ...

# %%
for x,y,z in os.walk(mri):
    print(z)
# Out:
# ['LICENSE']
# []
# ['1-01.dcm', '1-02.dcm', '1-03.dcm', '1-04.dcm', '1-05.dcm', '1-06.dcm', '1-07.dcm', '1-08.dcm', '1-09.dcm', '1-10.dcm', '1-11.dcm', '1-12.dcm', '1-13.dcm', '1-14.dcm', '1-15.dcm', '1-16.dcm', '1-17.dcm', '1-18.dcm', '1-19.dcm']
# ['1-01.dcm', '1-02.dcm', '1-03.dcm', '1-04.dcm', '1-05.dcm', '1-06.dcm', '1-07.dcm', '1-08.dcm', '1-09.dcm', '1-10.dcm', '1-11.dcm', '1-12.dcm', '1-13.dcm', '1-14.dcm', '1-15.dcm', '1-16.dcm', '1-17.dcm', '1-18.dcm', '1-19.dcm', '1-20.dcm', '1-21.dcm', '1-22.dcm', '1-23.dcm', '1-24.dcm', '1-25.dcm', '1-26.dcm', '1-27.dcm', '1-28.dcm', '1-29.dcm', '1-30.dcm', '1-31.dcm', '1-32.dcm', '1-33.dcm', '1-34.dcm', '1-35.dcm', '1-36.dcm', '1-37.dcm', '1-38.dcm', '1-39.dcm', '1-40.dcm', '1-41.dcm', '1-42.dcm', '1-43.dcm', '1-44.dcm', '1-45.dcm', '1-46.dcm', '1-47.dcm', '1-48.dcm', '1-49.dcm', '1-50.dcm', '1-51.dcm', '1-52.dcm', '1-53.dcm', '1-54.dcm', '1-55.dcm', '1-56.dcm', '1-57.dcm']
# ...

# %%
dicom = []

for x, y, z in os.walk(mri):
    for i in z:
        if i.endswith('dcm'):
            filename = os.path.join(x,i)
            dicom.append(filename)
dicom
# Out:
# ['C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-01.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-02.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-03.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-04.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-05.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-06.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-07.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-08.dcm',
# ...

# %%
for x,y,z in os.walk(mri):
    print(x)
    print(z)
# Out:
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx
# ['LICENSE']
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000
# []
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000\4.000000-t2tsetra-00702
# ['1-01.dcm', '1-02.dcm', '1-03.dcm', '1-04.dcm', '1-05.dcm', '1-06.dcm', '1-07.dcm', '1-08.dcm', '1-09.dcm', '1-10.dcm', '1-11.dcm', '1-12.dcm', '1-13.dcm', '1-14.dcm', '1-15.dcm', '1-16.dcm', '1-17.dcm', '1-18.dcm', '1-19.dcm']
# C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000\6.000000-ep2ddifftraDYNDIST-69284
# ...

# %%
mri=r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000\4.000000-t2tsetra-00702"
for x,y,z in os.walk(mri):
#     print(x)
    print(z)
# Out:
# ['1-01.dcm', '1-02.dcm', '1-03.dcm', '1-04.dcm', '1-05.dcm', '1-06.dcm', '1-07.dcm', '1-08.dcm', '1-09.dcm', '1-10.dcm', '1-11.dcm', '1-12.dcm', '1-13.dcm', '1-14.dcm', '1-15.dcm', '1-16.dcm', '1-17.dcm', '1-18.dcm', '1-19.dcm']

# %%
dicom = []

for x, y, z in os.walk(mri):
    for i in z:
        if i.endswith('dcm'):
            filename = os.path.join(x,i)
            dicom.append(filename)
dicom
# Out:
# ['C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-01.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-02.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-03.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-04.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-05.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-06.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-07.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\4.000000-t2tsetra-00702\\1-08.dcm',
# ...

# %%
reader = sitk.ImageSeriesReader()

# %%
reader.SetFileNames(dicom)
dir(reader)
# Out:
# ['Abort',
#  'AddCommand',
#  'DebugOff',
#  'DebugOn',
#  'Execute',
#  'GetDebug',
#  'GetFileNames',
#  'GetGDCMSeriesFileNames',
#  'GetGDCMSeriesIDs',
#  'GetGlobalDefaultCoordinateTolerance',
#  'GetGlobalDefaultDebug',
#  'GetGlobalDefaultDirectionTolerance',
#  'GetGlobalDefaultNumberOfThreads',
#  'GetGlobalDefaultThreader',
#  'GetGlobalWarningDisplay',
#  'GetImageIO',
#  'GetImageIOFromFileName',
#  'GetLoadPrivateTags',
#  'GetMetaData',
#  'GetMetaDataDictionaryArrayUpdate',
#  'GetMetaDataKeys',
#  'GetName',
#  'GetNumberOfThreads',
#  'GetNumberOfWorkUnits',
#  'GetOutputPixelType',
#  'GetProgress',
#  'GetRegisteredImageIOs',
#  'GlobalDefaultDebugOff',
#  'GlobalDefaultDebugOn',
#  'GlobalWarningDisplayOff',
#  'GlobalWarningDisplayOn',
#  'HasCommand',
#  'HasMetaDataKey',
#  'LoadPrivateTagsOff',
#  'LoadPrivateTagsOn',
#  'MetaDataDictionaryArrayUpdateOff',
#  'MetaDataDictionaryArrayUpdateOn',
#  'RemoveAllCommands',
#  'SetDebug',
#  'SetFileNames',
# ...

# %%
image = reader.Execute()

# %%
image.GetSize()
# Out:
# (384, 384, 19)

# %%
image.GetSpacing()
# Out:
# (0.5, 0.5, 2.9999999941936877)

# %%
sitk.WriteImage(image,r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000\4.000000-t2tsetra-00702\t2.dcm")

# %%
mri=r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000\6.000000-ep2ddifftraDYNDIST-69284"
for x,y,z in os.walk(mri):
#     print(x)
    print(z)
# Out:
# ['1-01.dcm', '1-02.dcm', '1-03.dcm', '1-04.dcm', '1-05.dcm', '1-06.dcm', '1-07.dcm', '1-08.dcm', '1-09.dcm', '1-10.dcm', '1-11.dcm', '1-12.dcm', '1-13.dcm', '1-14.dcm', '1-15.dcm', '1-16.dcm', '1-17.dcm', '1-18.dcm', '1-19.dcm', '1-20.dcm', '1-21.dcm', '1-22.dcm', '1-23.dcm', '1-24.dcm', '1-25.dcm', '1-26.dcm', '1-27.dcm', '1-28.dcm', '1-29.dcm', '1-30.dcm', '1-31.dcm', '1-32.dcm', '1-33.dcm', '1-34.dcm', '1-35.dcm', '1-36.dcm', '1-37.dcm', '1-38.dcm', '1-39.dcm', '1-40.dcm', '1-41.dcm', '1-42.dcm', '1-43.dcm', '1-44.dcm', '1-45.dcm', '1-46.dcm', '1-47.dcm', '1-48.dcm', '1-49.dcm', '1-50.dcm', '1-51.dcm', '1-52.dcm', '1-53.dcm', '1-54.dcm', '1-55.dcm', '1-56.dcm', '1-57.dcm']

# %%
dicom = []

for x, y, z in os.walk(mri):
    for i in z:
        if i.endswith('dcm'):
            filename = os.path.join(x,i)
            dicom.append(filename)
dicom
# Out:
# ['C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\6.000000-ep2ddifftraDYNDIST-69284\\1-01.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\6.000000-ep2ddifftraDYNDIST-69284\\1-02.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\6.000000-ep2ddifftraDYNDIST-69284\\1-03.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\6.000000-ep2ddifftraDYNDIST-69284\\1-04.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\6.000000-ep2ddifftraDYNDIST-69284\\1-05.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\6.000000-ep2ddifftraDYNDIST-69284\\1-06.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\6.000000-ep2ddifftraDYNDIST-69284\\1-07.dcm',
# ...

# %%
reader = sitk.ImageSeriesReader()

# %%
reader.SetFileNames(dicom)

# %%
image = reader.Execute()

# %%
image.GetSize()
# Out:
# (84, 128, 57)

# %%
image.GetSpacing()
# Out:
# (2.0, 2.0, 0.9642857124193995)

# %%
sitk.WriteImage(image,r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000\6.000000-ep2ddifftraDYNDIST-69284\dwi.dcm")

# %%
mri=r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000\7.000000-ep2ddifftraDYNDISTADC-48780"
for x,y,z in os.walk(mri):
#     print(x)
    print(z)
# Out:
# ['1-01.dcm', '1-02.dcm', '1-03.dcm', '1-04.dcm', '1-05.dcm', '1-06.dcm', '1-07.dcm', '1-08.dcm', '1-09.dcm', '1-10.dcm', '1-11.dcm', '1-12.dcm', '1-13.dcm', '1-14.dcm', '1-15.dcm', '1-16.dcm', '1-17.dcm', '1-18.dcm', '1-19.dcm']

# %%
dicom = []

for x, y, z in os.walk(mri):
    for i in z:
        if i.endswith('dcm'):
            filename = os.path.join(x,i)
            dicom.append(filename)
dicom
# Out:
# ['C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\7.000000-ep2ddifftraDYNDISTADC-48780\\1-01.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\7.000000-ep2ddifftraDYNDISTADC-48780\\1-02.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\7.000000-ep2ddifftraDYNDISTADC-48780\\1-03.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\7.000000-ep2ddifftraDYNDISTADC-48780\\1-04.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\7.000000-ep2ddifftraDYNDISTADC-48780\\1-05.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\7.000000-ep2ddifftraDYNDISTADC-48780\\1-06.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\7.000000-ep2ddifftraDYNDISTADC-48780\\1-07.dcm',
# ...

# %%
reader = sitk.ImageSeriesReader()

# %%
reader.SetFileNames(dicom)

# %%
image = reader.Execute()

# %%
image.GetSize()
# Out:
# (84, 128, 19)

# %%
image.GetSpacing()
# Out:
# (2.0, 2.0, 2.9999999941936877)

# %%
sitk.WriteImage(image,r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\ProstateX-0000\7.000000-ep2ddifftraDYNDISTADC-48780\adc.dcm")
