# %%
import os
import SimpleITK as sitk

# %%
mri=r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx"

for x,y,z in os.walk(mri):
    print(z)
# Out:
# ['LICENSE']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']
# ['adccor_0.dcm', 'dwicor_0.dcm', 't2.dcm']

# %%
dicom = []

for x, y, z in os.walk(mri):
    for i in z:
        if i.endswith('dcm'):
            filename = os.path.join(x,i)
            dicom.append(filename)
dicom
# Out:
# ['C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0000\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0001\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0001\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0001\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0002\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0002\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0002\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0003\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0003\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0003\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0004\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0004\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0004\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0005\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0005\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0005\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0006\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0006\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0006\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0007\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0007\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0007\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0008\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0008\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0008\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0009\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0009\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0009\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0010\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0010\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0010\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0011\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0011\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0011\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0012\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0012\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0012\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0013\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0013\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0013\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0014\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0014\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0014\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0015\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0015\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0015\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0016\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0016\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0016\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0017\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0017\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0017\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0018\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0018\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0018\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0019\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0019\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0019\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0020\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0020\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0020\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0021\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0021\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0021\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0022\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0022\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0022\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0023\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0023\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0023\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0024\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0024\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0024\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0025\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0025\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0025\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0026\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0026\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0026\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0027\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0027\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0027\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0028\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0028\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0028\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0029\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0029\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0029\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0030\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0030\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0030\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0031\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0031\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0031\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0032\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0032\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0032\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0033\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0033\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0033\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0034\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0034\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0034\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0035\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0035\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0035\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0036\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0036\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0036\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0037\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0037\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0037\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0038\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0038\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0038\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0039\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0039\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0039\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0040\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0040\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0040\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0041\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0041\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0041\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0042\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0042\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0042\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0043\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0043\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0043\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0044\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0044\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0044\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0045\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0045\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0045\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0046\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0046\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0046\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0047\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0047\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0047\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0048\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0048\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0048\\t2.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0049\\adccor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0049\\dwicor_0.dcm',
#  'C:\\Users\\Lenovo\\Downloads\\PROSTATE CANCER FILES\\PROSTATEx\\ProstateX-0049\\t2.dcm']

# %%
reader = sitk.ImageSeriesReader()

# %%
reader.SetFileNames(dicom)

# %%
reader.GetFileNames()

# %%
import SimpleITK as sitk
dir(sitk)

# %%
import SimpleITK as sitk

# Load the DICOM image
input_path = r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\t2.dcm"
input_image = sitk.ReadImage(input_path)

# Define the size of the cropped region
crop_size = (180, 180, 19)

# Define the center coordinate for cropping (based on the almost lesion coordinate)
center_coordinate = (178, 140, 0)

# Calculate the starting index for cropping
start_index = [int(center_coordinate[i] - crop_size[i] / 2) for i in range(3)]

# Ensure the cropping region lies within the bounds of the input image
for i in range(3):
    if start_index[i] < 0:
        start_index[i] = 0
    elif start_index[i] + crop_size[i] > input_image.GetSize()[i]:
        start_index[i] = input_image.GetSize()[i] - crop_size[i]

# Define the region to crop
region_to_crop = [slice(start_index[i], start_index[i] + crop_size[i]) for i in range(3)]

# Crop the image
cropped_image = input_image[region_to_crop]

# Save the cropped image
output_path = r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\t2cropped_image.dcm"
sitk.WriteImage(cropped_image, output_path)

# Print the shape of the cropped image
print("Shape of the cropped image:", cropped_image.GetSize())

# %%
import SimpleITK as sitk

# Load the DICOM image
input_path = r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\adccor_0.dcm"
input_image = sitk.ReadImage(input_path)

# Define the size of the cropped region
crop_size = (180, 180, 19)

# Define the center coordinate for cropping (based on the almost lesion coordinate)
center_coordinate = (178, 140, 0)

# Calculate the starting index for cropping
start_index = [int(center_coordinate[i] - crop_size[i] / 2) for i in range(3)]

# Ensure the cropping region lies within the bounds of the input image
for i in range(3):
    if start_index[i] < 0:
        start_index[i] = 0
    elif start_index[i] + crop_size[i] > input_image.GetSize()[i]:
        start_index[i] = input_image.GetSize()[i] - crop_size[i]

# Define the region to crop
region_to_crop = [slice(start_index[i], start_index[i] + crop_size[i]) for i in range(3)]

# Crop the image
cropped_image = input_image[region_to_crop]

# Save the cropped image
output_path = r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\adccropped_image.dcm"
sitk.WriteImage(cropped_image, output_path)

# Print the shape of the cropped image
print("Shape of the cropped image:", cropped_image.GetSize())

# %%
import SimpleITK as sitk

# Load the DICOM image
input_path = r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\dwicor_0.dcm"
input_image = sitk.ReadImage(input_path)

# Define the size of the cropped region
crop_size = (180, 180, 19)

# Define the center coordinate for cropping (based on the almost lesion coordinate)
center_coordinate = (178, 140, 0)

# Calculate the starting index for cropping
start_index = [int(center_coordinate[i] - crop_size[i] / 2) for i in range(3)]

# Ensure the cropping region lies within the bounds of the input image
for i in range(3):
    if start_index[i] < 0:
        start_index[i] = 0
    elif start_index[i] + crop_size[i] > input_image.GetSize()[i]:
        start_index[i] = input_image.GetSize()[i] - crop_size[i]

# Define the region to crop
region_to_crop = [slice(start_index[i], start_index[i] + crop_size[i]) for i in range(3)]

# Crop the image
cropped_image = input_image[region_to_crop]

# Save the cropped image
output_path = r"C:\Users\Lenovo\Downloads\PROSTATE CANCER FILES\PROSTATEx\dwicropped_image.dcm"
sitk.WriteImage(cropped_image, output_path)

# Print the shape of the cropped image
print("Shape of the cropped image:", cropped_image.GetSize())
